# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset('tips')
crashes = sns.load_dataset('car_crashes')
crashes.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x='tip', y='total_bill', data=tips, hue='day');

# %% [markdown]
# # **Distribution plots in Seaborn**

# %% [markdown]
# **1.Distribution Plot**

# %%
sns.distplot(crashes['not_distracted'], kde=False)
# Out:
# C:\Users\storm\anaconda3\envs\learn-env\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='not_distracted'>

# %% [markdown]
# **Joint Plot**

# %%
sns.jointplot(x='speeding', y='alcohol', data=crashes, kind='kde');

# %% [markdown]
# **KDE Plot**

# %%
#KDE = Kernel Density Estimation
sns.kdeplot(crashes['alcohol']);

# %% [markdown]
# **Pair Plot**

# %%
sns.pairplot(tips, hue='sex', palette='bright');

# %% [markdown]
# **Rug Plot**

# %%
sns.rugplot(tips['tip']);

# %% [markdown]
# **Styling**

# %%
sns.set_style('dark')

sns.set_context('paper', font_scale=1.5)

sns.jointplot(x='speeding', y='alcohol', data=crashes);

# %% [markdown]
# # Categorical Plots

# %% [markdown]
# ## Bar Plots

# %%
sns.barplot(x='sex', y='total_bill', data=tips);

# %% [markdown]
# ## Count Plots

# %%
#counts the occurence of a particular value. -Just like a histogram
sns.countplot(x='sex', data=tips);

# %% [markdown]
# ## Box Plot

# %%
sns.boxplot(x='day', y='total_bill', data=tips, hue='sex');

# %% [markdown]
# ## Violin Plot

# %%
sns.violinplot(x='day', y='total_bill', data=tips, hue='sex', split=True);

# %% [markdown]
# ## Strip Plot

# %%
sns.set_style('white')

plt.figure(figsize=(8,5))

sns.stripplot(x='day', y='total_bill', data=tips, hue='sex', dodge=True);

# %% [markdown]
# ## Palette

# %%
#Check Matplotlib color map on internet to see different kinds of palettes
plt.figure(figsize=(8,5))

sns.set_style('dark')
sns.set_context('paper', font_scale=1.5)
sns.stripplot(x='day', y='total_bill', data=tips, hue='sex', dodge=True, palette='magma');

# %% [markdown]
# # Matrix Plots

# %% [markdown]
# ## Heat Maps

# %%
plt.figure(figsize=(8,6))

crashes_mx = crashes.corr()
crashes_mx

sns.heatmap(crashes_mx, annot=True, cmap='Blues');

# %%
flights = sns.load_dataset('flights')
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights = flights.pivot(index='month', columns='year', values='passengers')
flights
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'month'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-1f7474fc23f7> in <module>
# ----> 1 flights = flights.pivot(index='month', columns='year', values='passengers')
#       2 flights
#
# ...

# %%
sns.heatmap(flights, cmap='Blues', linecolor='white', linewidth=1);

# %% [markdown]
# ## Cluster Map

# %%
iris = sns.load_dataset('iris')
species = iris.pop('species')
sns.clustermap(data=iris)
